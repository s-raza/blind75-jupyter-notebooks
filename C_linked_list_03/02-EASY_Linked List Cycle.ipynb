# %% [markdown]
# https://leetcode.com/problems/linked-list-cycle/

# %%
from typing import Optional
from C_linked_list_03.linked_list import ListNode

class Solution:
    def hasCycle(self, head: Optional[ListNode]) -> bool:
        
        return

# %%
from C_linked_list_03.linked_list import LinkedList
from C_linked_list_03.solver import solve


problems = [
    
    ([[3,2,0,-4]], True),
    ([[1,2]], True),
    ([[1]], False),
       
]

solution = Solution().hasCycle
solve(problems, solution)
